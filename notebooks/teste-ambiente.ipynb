# %%
import pandas as pd
import numpy as np
import matplotlib

print("Ambiente Data Science configurado com sucesso! 🐼🚀")
# Verificar as versões das bibliotecas
print(f"✅ Pandas Versão: {pd.__version__}")
print(f"✅ NumPy Versão: {np.__version__}")
print(f"✅ Matplotlib Versão: {matplotlib.__version__}")
# Out:
# Ambiente Data Science configurado com sucesso! 🐼🚀
# ✅ Pandas Versão: 2.3.3
# ✅ NumPy Versão: 2.3.5
# ✅ Matplotlib Versão: 3.10.6
